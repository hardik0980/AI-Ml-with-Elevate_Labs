# %%
import pandas as pd
import numpy as np

# %%
titanic_data = pd.read_csv("Titanic-Dataset.csv")

# %%
# top 5 rows
titanic_data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
Total_Rows = titanic_data.shape[0]
Total_Cols = titanic_data.shape[1]
print("Total Rows is :",Total_Rows)
print("Total columns is :", Total_Cols)
# Out:
# Total Rows is : 891
# Total columns is : 12

# %%
print( "\n Information about the Titanic dataset : \n " )
titanic_data.info()
# Out:
#  Information about the Titanic dataset :
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
numerical_col = titanic_data.select_dtypes(include=["int64", "float64"]).columns.tolist()
print("Numerical columns is here : \n ",numerical_col)
# Out:
# Numerical columns is here :
#   ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
Categorical_col = titanic_data.select_dtypes(include=["object"]).columns.tolist()
print("Categical columns is here : \n",Categorical_col)
# Out:
# Categical columns is here :
#  ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %% [markdown]
# # 1.Generate summary statistics (mean, median, std, etc.).

# %%
titanic_data.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
titanic_data.describe(include="O")
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
titanic_data.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %% [markdown]
# # 2. Create Histograms and Boxplots for Numeric Features

# %%
import matplotlib.pyplot as plt

titanic_data[numerical_col].hist(figsize=(10,10))
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

for col in numerical_col:

    plt.figure(figsize=(6, 2))
    sns.boxplot(x=titanic_data[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %% [markdown]
# # 3. Pairplot and Correlation Matrix

# %%
sns.pairplot(titanic_data)
plt.show()

# %%
numerical_col = titanic_data.select_dtypes(include=["int64","float64"])
numerical = pd.DataFrame(numerical_col)
numerical
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
sns.pairplot(numerical_col)
plt.show()

# %% [markdown]
# # Correlation Matrix

# %%
correlation = numerical_col.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# # 4.Identify patterns, trends, or anomalies in the data.

# %% [raw]
# Patterns:
#
# Passengers who paid higher Fare had a higher chance of survival (correlation with Survived: +0.26).
#
# Passengers from lower classes (Pclass) were less likely to survive (correlation: -0.34).
#
# The Pclass feature shows a clear trend: most passengers belonged to the 3rd class, indicating a skew towards lower ticket classes.
#
# Most passengers were aged between 20 and 40, indicating a younger demographic on board.
#
#
# A large number of passengers paid less than 50, but a few paid much higher fares, creating a right-skewed distribution.

# %% [raw]
# Trends:
# The survival rate is imbalanced, with fewer passengers surviving than not.

# %% [raw]
# Anomalies (Outliers):
#
# While the shown boxplots (PassengerId, Survived, and Pclass) do not display visible outliers, other numerical columns like Fare, Age, SibSp, and Parch (not shown here) are known to contain outliers:
#
# Fare: Some passengers paid extremely high fares.
#
# Age: A few passengers were unusually old compared to the rest.
#
# SibSp/Parch: Some passengers had an unusually large number of siblings/spouses or parents/children onboard.

# %% [markdown]
# # 5. Make basic feature-level inferences from visuals

# %% [raw]
# Based on the boxplots provided, we can infer the following:
#
# PassengerId:
#
# The data is uniformly distributed across all passenger IDs.
# It behaves like a unique identifier, so it doesn’t carry predictive value on its own.
#
# Survived:
# The values are binary (0 or 1), indicating two clear classes: survived and not survived.
#
# The boxplot shows no outliers due to the binary nature.
#
# The class imbalance (visually seen in bar plots, not in boxplots) can affect model performance and may require handling (e.g., with sampling techniques).
#
# Pclass (Passenger Class):
#
# The data is skewed towards the 3rd class, with a higher concentration of passengers in lower classes.
#
# Since class may be linked with survival chances, this feature could be important for prediction.
